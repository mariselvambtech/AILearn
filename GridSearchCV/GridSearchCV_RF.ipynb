# %%
import pandas as pd

# %%
dataset = pd.read_csv("insurance_pre.csv")

# %%
dataset.head()
# Out:
#    age     sex     bmi  children smoker      charges
# 0   19  female  27.900         0    yes  16884.92400
# 1   18    male  33.770         1     no   1725.55230
# 2   28    male  33.000         3     no   4449.46200
# 3   33    male  22.705         0     no  21984.47061
# 4   32    male  28.880         0     no   3866.85520

# %%
dataset = pd.get_dummies(dataset,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent= dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent = dataset[['charges']]

# %%
dependent = dataset[['charges']].values.ravel()

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
param_grid = {'n_estimators': [50, 100, 150],
              'criterion':['squared_error','absolute_error','friedman_mse','poisson'],
              'max_features':['sqrt','log2',None]}

# %%
model = GridSearchCV(RandomForestRegressor(random_state=42),param_grid,refit=True,verbose=3,n_jobs=-1)

# %%
model.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# GridSearchCV(estimator=RandomForestRegressor(random_state=42), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['sqrt', 'log2', None],
#                          'n_estimators': [50, 100, 150]},
#              verbose=3)

# %%
re = model.cv_results_

# %%
re
# Out:
# {'mean_fit_time': array([0.10527005, 0.20810099, 0.295013  , 0.09593358, 0.19919868,
#         0.30830755, 0.14563212, 0.26300302, 0.38220005, 0.38884859,
#         0.76529279, 1.75849218, 0.38000846, 1.03479638, 2.03781338,
#         1.25211682, 2.718964  , 3.40100188, 0.1964572 , 0.37029023,
#         0.50890675, 0.14878416, 0.28657622, 0.46900783, 0.23073134,
#         0.41781235, 0.60031471, 0.23321991, 0.44874015, 0.69949117,
#         0.21610017, 0.44568357, 0.67590728, 0.27678485, 0.57296019,
#         0.7071281 ]),
#  'std_fit_time': array([0.00461873, 0.01343788, 0.00969036, 0.00121586, 0.01339871,
#         0.01727058, 0.01250956, 0.01089291, 0.01560661, 0.0045253 ,
#         0.00721859, 0.1487877 , 0.0048083 , 0.06476441, 0.11509802,
#         0.20265973, 0.15477401, 0.10264416, 0.03697809, 0.02075154,
#         0.03585133, 0.01763601, 0.01760132, 0.0197552 , 0.01935913,
#         0.0170951 , 0.02563786, 0.01342617, 0.02293488, 0.01504714,
# ...

# %%
model.best_params_
# Out:
# {'criterion': 'squared_error', 'max_features': 'sqrt', 'n_estimators': 150}

# %%
pd.DataFrame.from_dict(re)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.105270      0.004619         0.005094        0.000885
# 1        0.208101      0.013438         0.009795        0.001918
# 2        0.295013      0.009690         0.011917        0.001960
# 3        0.095934      0.001216         0.004737        0.000680
# 4        0.199199      0.013399         0.009347        0.001496
# 5        0.308308      0.017271         0.010421        0.001189
# 6        0.145632      0.012510         0.005109        0.000970
# 7        0.263003      0.010893         0.007510        0.001096
# 8        0.382200      0.015607         0.009306        0.000245
# 9        0.388849      0.004525         0.004301        0.000872
# 10       0.765293      0.007219         0.006904        0.000735
# 11       1.758492      0.148788         0.022121        0.019477
# 12       0.380008      0.004808         0.004502        0.000776
# ...

# %%
dataset.head()
# Out:
#    age     bmi  children      charges  sex_male  smoker_yes
# 0   19  27.900         0  16884.92400     False        True
# 1   18  33.770         1   1725.55230      True       False
# 2   28  33.000         3   4449.46200      True       False
# 3   33  22.705         0  21984.47061      True       False
# 4   32  28.880         0   3866.85520      True       False

# %%
model.predict([[12,26,0,0,1]])
# Out:
# C:\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([17190.9298192])
