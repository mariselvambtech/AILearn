# %%
import pandas as pd

# %%
dataset = pd.read_csv("insurance_pre.csv")

# %%
dataset.head()
# Out:
#    age     sex     bmi  children smoker      charges
# 0   19  female  27.900         0    yes  16884.92400
# 1   18    male  33.770         1     no   1725.55230
# 2   28    male  33.000         3     no   4449.46200
# 3   33    male  22.705         0     no  21984.47061
# 4   32    male  28.880         0     no   3866.85520

# %%
dataset = pd.get_dummies(dataset,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent= dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent = dataset[['charges']]

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
param_grid = {'criterion': ['squared_error', 'friedman_mse', 'absolute_error','poisson'],
              'splitter':['best','random']
              }

# %%
model = GridSearchCV(DecisionTreeRegressor(random_state=42),param_grid,refit=True,verbose=3,n_jobs=-1)

# %%
model.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# GridSearchCV(estimator=DecisionTreeRegressor(random_state=42), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re = model.cv_results_

# %%
model.best_params_
# Out:
# {'criterion': 'absolute_error', 'splitter': 'random'}

# %%
pd.DataFrame.from_dict(re)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.004200      0.000749         0.001999        0.000633
# 1       0.004702      0.000602         0.002310        0.000250
# 2       0.004591      0.000650         0.001525        0.000449
# 3       0.004752      0.000500         0.002399        0.000489
# 4       0.024414      0.002333         0.001703        0.000603
# 5       0.017208      0.002807         0.002406        0.000376
# 6       0.008108      0.000491         0.002201        0.000399
# 7       0.004259      0.000491         0.001201        0.000400
#
#   param_criterion param_splitter  \
# 0   squared_error           best
# 1   squared_error         random
# 2    friedman_mse           best
# 3    friedman_mse         random
# 4  absolute_error           best
# 5  absolute_error         random
# 6         poisson           best
# 7         poisson         random
#
#                                               params  split0_test_score  \
# 0  {'criterion': 'squared_error', 'splitter': 'be...           0.722699
# 1  {'criterion': 'squared_error', 'splitter': 'ra...           0.694849
# 2  {'criterion': 'friedman_mse', 'splitter': 'best'}           0.714127
# 3  {'criterion': 'friedman_mse', 'splitter': 'ran...           0.690003
# 4  {'criterion': 'absolute_error', 'splitter': 'b...           0.744125
# 5  {'criterion': 'absolute_error', 'splitter': 'r...           0.729276
# 6       {'criterion': 'poisson', 'splitter': 'best'}           0.752001
# 7     {'criterion': 'poisson', 'splitter': 'random'}           0.708717
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.646571           0.728189           0.748109           0.677683
# 1           0.605583           0.741947           0.661506           0.699256
# 2           0.644072           0.731422           0.748165           0.679374
# 3           0.611482           0.733722           0.666538           0.679970
# 4           0.583722           0.703555           0.728541           0.739683
# 5           0.669442           0.734326           0.729414           0.733166
# 6           0.656450           0.755663           0.713776           0.698949
# 7           0.579778           0.768602           0.683219           0.700952
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.704650        0.037065                3
# 1         0.680628        0.045402                7
# 2         0.703432        0.037420                4
# 3         0.676343        0.039484                8
# 4         0.699925        0.059782                5
# 5         0.719125        0.024922                1
# 6         0.715368        0.036631                2
# 7         0.688254        0.061365                6

# %%
dataset.head()
# Out:
#    age     bmi  children      charges  sex_male  smoker_yes
# 0   19  27.900         0  16884.92400     False        True
# 1   18  33.770         1   1725.55230      True       False
# 2   28  33.000         3   4449.46200      True       False
# 3   33  22.705         0  21984.47061      True       False
# 4   32  28.880         0   3866.85520      True       False

# %%
model.predict([[12,26,0,0,1]])
# Out:
# C:\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([26125.67477])
