# %%
import pandas as pd

# %%
dataset = pd.read_csv("insurance_pre.csv")

# %%
dataset.head()
# Out:
#    age     sex     bmi  children smoker      charges
# 0   19  female  27.900         0    yes  16884.92400
# 1   18    male  33.770         1     no   1725.55230
# 2   28    male  33.000         3     no   4449.46200
# 3   33    male  22.705         0     no  21984.47061
# 4   32    male  28.880         0     no   3866.85520

# %%
dataset = pd.get_dummies(dataset,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent= dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent = dataset[['charges']]

# %%
dependent = dataset[['charges']].values.ravel()

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.svm import SVR

# %%
param_grid = {'kernel': ['rbf', 'sigmoid', 'linear'],
              'C':[10,100,1000,2000,3000],
              'gamma':['auto','scale']}

# %%
model = GridSearchCV(SVR(),param_grid,refit=True,verbose=3,n_jobs=-1)

# %%
model.fit(independent,dependent)#taking long time to fit for poly
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 3000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf', 'sigmoid', 'linear']},
#              verbose=3)

# %%
re = model.cv_results_

# %%
re
# Out:
# {'mean_fit_time': array([0.07099676, 0.04107504, 0.05402451, 0.05898218, 0.0578692 ,
#         0.05319767, 0.07280631, 0.04016061, 0.0970036 , 0.04491539,
#         0.05834799, 0.10067601, 0.08116064, 0.03772511, 0.36596718,
#         0.04743814, 0.05716572, 0.38015904, 0.14642625, 0.03722949,
#         0.59807038, 0.05573587, 0.05673637, 0.5702373 , 0.15333209,
#         0.0427238 , 0.96140537, 0.05923777, 0.06446719, 0.94553618]),
#  'std_fit_time': array([0.0093068 , 0.00386472, 0.00428611, 0.008692  , 0.00304689,
#         0.00513206, 0.01289676, 0.00164391, 0.0063983 , 0.00049567,
#         0.00607554, 0.00462375, 0.01134832, 0.00320523, 0.03872859,
#         0.00252044, 0.00343046, 0.03965806, 0.03515085, 0.00051024,
#         0.03164099, 0.00383136, 0.00375115, 0.02236191, 0.02404117,
#         0.00512051, 0.25519077, 0.00686266, 0.00486888, 0.24017853]),
#  'mean_score_time': array([0.02352934, 0.00781317, 0.00720692, 0.02463312, 0.01191812,
#         0.00710597, 0.0257257 , 0.00760913, 0.00612445, 0.02351985,
#         0.01120973, 0.00700827, 0.02306471, 0.00750699, 0.00690207,
#         0.02190194, 0.01050954, 0.00580506, 0.02511382, 0.00710635,
#         0.00540442, 0.02501702, 0.01220798, 0.00479941, 0.0218636 ,
#         0.00695624, 0.00810361, 0.02451372, 0.0132812 , 0.00740552]),
#  'std_score_time': array([9.99488873e-04, 4.00212225e-04, 1.29396362e-03, 3.23760690e-03,
#         1.02516832e-03, 5.84723509e-04, 2.54349925e-03, 1.01915795e-03,
#         7.45234566e-04, 1.22770171e-03, 1.40416657e-03, 8.96472657e-04,
#         2.35820619e-03, 1.09562697e-03, 1.19991175e-03, 5.53293587e-04,
#         2.74088056e-06, 8.73168580e-04, 3.07386109e-03, 5.82736474e-04,
#         1.71847086e-03, 5.06447044e-03, 1.88752754e-03, 1.16561528e-03,
#         4.35797875e-04, 6.77881884e-04, 1.98684716e-03, 3.90114454e-03,
#         2.63741953e-03, 8.01087008e-04]),
#  'param_C': masked_array(data=[10, 10, 10, 10, 10, 10, 100, 100, 100, 100, 100, 100,
#                     1000, 1000, 1000, 1000, 1000, 1000, 2000, 2000, 2000,
#                     2000, 2000, 2000, 3000, 3000, 3000, 3000, 3000, 3000],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False],
#         fill_value=999999),
#  'param_gamma': masked_array(data=['auto', 'auto', 'auto', 'scale', 'scale', 'scale',
#                     'auto', 'auto', 'auto', 'scale', 'scale', 'scale',
#                     'auto', 'auto', 'auto', 'scale', 'scale', 'scale',
#                     'auto', 'auto', 'auto', 'scale', 'scale', 'scale',
#                     'auto', 'auto', 'auto', 'scale', 'scale', 'scale'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_kernel': masked_array(data=['rbf', 'sigmoid', 'linear', 'rbf', 'sigmoid', 'linear',
#                     'rbf', 'sigmoid', 'linear', 'rbf', 'sigmoid', 'linear',
#                     'rbf', 'sigmoid', 'linear', 'rbf', 'sigmoid', 'linear',
#                     'rbf', 'sigmoid', 'linear', 'rbf', 'sigmoid', 'linear',
#                     'rbf', 'sigmoid', 'linear', 'rbf', 'sigmoid', 'linear'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'C': 10, 'gamma': 'auto', 'kernel': 'rbf'},
#   {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'},
#   {'C': 10, 'gamma': 'auto', 'kernel': 'linear'},
#   {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'},
#   {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'},
#   {'C': 10, 'gamma': 'scale', 'kernel': 'linear'},
#   {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'},
#   {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'},
#   {'C': 100, 'gamma': 'auto', 'kernel': 'linear'},
#   {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'},
#   {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'},
#   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'},
#   {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'},
#   {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'},
#   {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'},
#   {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'},
#   {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmoid'},
#   {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'},
#   {'C': 2000, 'gamma': 'auto', 'kernel': 'rbf'},
#   {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoid'},
#   {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'},
#   {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'},
#   {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmoid'},
#   {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'},
#   {'C': 3000, 'gamma': 'auto', 'kernel': 'rbf'},
#   {'C': 3000, 'gamma': 'auto', 'kernel': 'sigmoid'},
#   {'C': 3000, 'gamma': 'auto', 'kernel': 'linear'},
#   {'C': 3000, 'gamma': 'scale', 'kernel': 'rbf'},
#   {'C': 3000, 'gamma': 'scale', 'kernel': 'sigmoid'},
#   {'C': 3000, 'gamma': 'scale', 'kernel': 'linear'
#         -7.90453873e-02, -1.04753143e-01,  6.93778210e-01, -1.44192505e-01,
#         -2.21544064e+00,  6.93778210e-01, -3.18076638e-02, -1.04753143e-01,
#          6.86466559e-01, -1.33399856e-01, -7.78112551e+00,  6.86466559e-01,
#          1.55058641e-02, -1.04753143e-01,  6.73913747e-01, -1.20018118e-01,
#         -1.69838559e+01,  6.73913747e-01]),
#  'std_test_score': array([0.01230291, 0.012107  , 0.03467157, 0.01645872, 0.01202922,
#         0.03467157, 0.01069937, 0.012107  , 0.01812189, 0.03551124,
#         0.01426274, 0.01812189, 0.02186496, 0.012107  , 0.02295499,
#         0.036262  , 0.25540914, 0.02295499, 0.02069884, 0.012107  ,
#         0.04505602, 0.03549164, 0.82155661, 0.04505602, 0.01821678,
#         0.012107  , 0.03987603, 0.03457804, 1.91478335, 0.03987603]),
#  'rank_test_score': array([16, 17, 10, 15, 22, 10, 14, 17,  7, 27, 25,  7, 13, 17,  1, 26, 28,
#          1, 12, 17,  3, 24, 29,  3,  9, 17,  5, 23, 30,  5])}

# %%
model.best_params_
# Out:
# {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}

# %%
pd.DataFrame.from_dict(re)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.070997      0.009307         0.023529        0.000999       10
# 1        0.041075      0.003865         0.007813        0.000400       10
# 2        0.054025      0.004286         0.007207        0.001294       10
# 3        0.058982      0.008692         0.024633        0.003238       10
# 4        0.057869      0.003047         0.011918        0.001025       10
# 5        0.053198      0.005132         0.007106        0.000585       10
# 6        0.072806      0.012897         0.025726        0.002543      100
# 7        0.040161      0.001644         0.007609        0.001019      100
# 8        0.097004      0.006398         0.006124        0.000745      100
# 9        0.044915      0.000496         0.023520        0.001228      100
# 10       0.058348      0.006076         0.011210        0.001404      100
# 11       0.100676      0.004624         0.007008        0.000896      100
# 12       0.081161      0.011348         0.023065        0.002358     1000
# 13       0.037725      0.003205         0.007507        0.001096     1000
# 14       0.365967      0.038729         0.006902        0.001200     1000
# 15       0.047438      0.002520         0.021902        0.000553     1000
# 16       0.057166      0.003430         0.010510        0.000003     1000
# 17       0.380159      0.039658         0.005805        0.000873     1000
# 18       0.146426      0.035151         0.025114        0.003074     2000
# 19       0.037229      0.000510         0.007106        0.000583     2000
# 20       0.598070      0.031641         0.005404        0.001718     2000
# 21       0.055736      0.003831         0.025017        0.005064     2000
# 22       0.056736      0.003751         0.012208        0.001888     2000
# 23       0.570237      0.022362         0.004799        0.001166     2000
# 24       0.153332      0.024041         0.021864        0.000436     3000
# 25       0.042724      0.005121         0.006956        0.000678     3000
# 26       0.961405      0.255191         0.008104        0.001987     3000
# 27       0.059238      0.006863         0.024514        0.003901     3000
# 28       0.064467      0.004869         0.013281        0.002637     3000
# 29       0.945536      0.240179         0.007406        0.000801     3000
#
#    param_gamma param_kernel  \
# 0         auto          rbf
# 1         auto      sigmoid
# 2         auto       linear
# 3        scale          rbf
# 4        scale      sigmoid
# 5        scale       linear
# 6         auto          rbf
# 7         auto      sigmoid
# 8         auto       linear
# 9        scale          rbf
# 10       scale      sigmoid
# 11       scale       linear
# 12        auto          rbf
# 13        auto      sigmoid
# 14        auto       linear
# 15       scale          rbf
# 16       scale      sigmoid
# 17       scale       linear
# 18        auto          rbf
# 19        auto      sigmoid
# 20        auto       linear
# 21       scale          rbf
# 22       scale      sigmoid
# 23       scale       linear
# 24        auto          rbf
# 25        auto      sigmoid
# 26        auto       linear
# 27       scale          rbf
# 28       scale      sigmoid
# 29       scale       linear
#
#                                                params  split0_test_score  \
# 0         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}          -0.113791
# 1     {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.115328
# 2      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}          -0.018943
# 3        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}          -0.110409
# 4    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}          -0.116743
# 5     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}          -0.018943
# 6        {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}          -0.100012
# 7    {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.115328
# 8     {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.559313
# 9       {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}          -0.160182
# 10  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}          -0.142455
# 11   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.559313
# 12      {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}          -0.080692
# 13  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.115328
# 14   {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.736398
# 15     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}          -0.155430
# 16  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...          -2.043140
# 17  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.736398
# 18      {'C': 2000, 'gamma': 'auto', 'kernel': 'rbf'}          -0.033126
# 19  {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.115328
# 20   {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}           0.682349
# 21     {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'}          -0.143510
# 22  {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmo...          -7.209317
# 23  {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}           0.682349
# 24      {'C': 3000, 'gamma': 'auto', 'kernel': 'rbf'}           0.011741
# 25  {'C': 3000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.115328
# 26   {'C': 3000, 'gamma': 'auto', 'kernel': 'linear'}           0.677778
# 27     {'C': 3000, 'gamma': 'scale', 'kernel': 'rbf'}          -0.128958
# 28  {'C': 3000, 'gamma': 'scale', 'kernel': 'sigmo...         -15.561853
# 29  {'C': 3000, 'gamma': 'scale', 'kernel': 'linear'}           0.677778
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0           -0.110741          -0.079156          -0.103389
# 1           -0.113567          -0.081608          -0.106067
# 2            0.029886           0.022167           0.003112
# 3           -0.097459          -0.074488          -0.099597
# 4           -0.119312          -0.085214          -0.108210
# 5            0.029886           0.022167           0.003112
# 6           -0.098456          -0.072981          -0.096615
# 7           -0.113567          -0.081608          -0.106067
# 8            0.521798           0.547691           0.538805
# 9           -0.107253          -0.123430          -0.137753
# 10          -0.160831          -0.117544          -0.137984
# 11           0.521798           0.547691           0.538805
# 12          -0.054347          -0.062876          -0.079329
# 13          -0.113567          -0.081608          -0.106067
# 14           0.675162           0.680002           0.699377
# 15          -0.098267          -0.123724          -0.137137
# 16          -2.686121          -2.194563          -2.210858
# 17           0.675162           0.680002           0.699377
# 18          -0.002835          -0.026545          -0.029140
# 19          -0.113567          -0.081608          -0.106067
# 20           0.630642           0.750714           0.646368
# 21          -0.087595          -0.113312          -0.128591
# 22          -9.282940          -7.776578          -7.745074
# 23           0.630642           0.750714           0.646368
# 24           0.043659           0.013383           0.021694
# 25          -0.113567          -0.081608          -0.106067
# 26           0.626814           0.732806           0.633479
# 27          -0.075578          -0.100199          -0.116051
# 28         -20.498908         -17.095474         -16.750877
# 29           0.626814           0.732806           0.633479
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.106488        -0.102713        0.012303               16
# 1           -0.107195        -0.104753        0.012107               17
# 2           -0.066653        -0.006086        0.034672               10
# 3           -0.124428        -0.101276        0.016459               15
# 4           -0.108716        -0.107639        0.012029               22
# 5           -0.066653        -0.006086        0.034672               10
# 6           -0.102232        -0.094059        0.010699               14
# 7           -0.107195        -0.104753        0.012107               17
# 8            0.508518         0.535225        0.018122                7
# 9           -0.209551        -0.147634        0.035511               27
# 10          -0.130402        -0.137843        0.014263               25
# 11           0.508518         0.535225        0.018122                7
# 12          -0.117983        -0.079045        0.021865               13
# 13          -0.107195        -0.104753        0.012107               17
# 14           0.677952         0.693778        0.022955                1
# 15          -0.206405        -0.144193        0.036262               26
# 16          -1.942521        -2.215441        0.255409               28
# 17           0.677952         0.693778        0.022955                1
# 18          -0.067392        -0.031808        0.020699               12
# 19          -0.107195        -0.104753        0.012107               17
# 20           0.722261         0.686467        0.045056                3
# 21          -0.193992        -0.133400        0.035492               24
# 22          -6.891719        -7.781126        0.821557               29
# 23           0.722261         0.686467        0.045056                3
# 24          -0.012948         0.015506        0.018217                9
# 25          -0.107195        -0.104753        0.012107               17
# 26           0.698692         0.673914        0.039876                5
# 27          -0.179304        -0.120018        0.034578               23
# 28         -15.012168       -16.983856        1.914783               30
# 29           0.698692         0.673914        0.039876                5

# %%
dataset.head()
# Out:
#    age     bmi  children      charges  sex_male  smoker_yes
# 0   19  27.900         0  16884.92400     False        True
# 1   18  33.770         1   1725.55230      True       False
# 2   28  33.000         3   4449.46200      True       False
# 3   33  22.705         0  21984.47061      True       False
# 4   32  28.880         0   3866.85520      True       False

# %%
model.predict([[12,26,0,0,1]])
# Out:
# C:\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# array([24054.24568652])
