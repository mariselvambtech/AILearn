# %%
import pandas as pd

# %%
dataset = pd.read_csv("insurance_pre.csv")

# %%
dataset.head()
# Out:
#    age     sex     bmi  children smoker      charges
# 0   19  female  27.900         0    yes  16884.92400
# 1   18    male  33.770         1     no   1725.55230
# 2   28    male  33.000         3     no   4449.46200
# 3   33    male  22.705         0     no  21984.47061
# 4   32    male  28.880         0     no   3866.85520

# %%
dataset = pd.get_dummies(dataset,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent= dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent = dataset[['charges']].values.ravel()

# %%
from sklearn.model_selection import GridSearchCV

# %%
from lightgbm import LGBMRegressor

# %%
param_grid = {'n_estimators': [5,10,30,50,100],
              'learning_rate':[0.01,0.1,0.5,1.0,1.1],
              'importance_type': ['split', 'gain']
              }

# %%
model = GridSearchCV(LGBMRegressor(random_state=42),param_grid,refit=True,verbose=3,n_jobs=-1)

# %%
model.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000291 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 313
# [LightGBM] [Info] Number of data points in the train set: 1338, number of used features: 5
# [LightGBM] [Info] Start training from score 13270.422260
# GridSearchCV(estimator=LGBMRegressor(random_state=42), n_jobs=-1,
#              param_grid={'importance_type': ['split', 'gain'],
#                          'learning_rate': [0.01, 0.1, 0.5, 1.0, 1.1],
#                          'n_estimators': [5, 10, 30, 50, 100]},
#              verbose=3)

# %%
re = model.cv_results_

# %%
model.best_params_
# Out:
# {'importance_type': 'split', 'learning_rate': 0.1, 'n_estimators': 30}

# %%
pd.DataFrame.from_dict(re)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.738911      0.393781         0.002801    2.433370e-04
# 1        0.879348      0.272872         0.002501    4.483036e-04
# 2        1.524829      0.315485         0.002884    4.902795e-04
# 3        2.247724      0.176998         0.003231    3.892753e-04
# 4        4.213353      0.160092         0.002905    3.757413e-04
# 5        0.222044      0.003712         0.002200    4.002095e-04
# 6        0.419702      0.007301         0.002501    4.468184e-04
# 7        1.251037      0.018378         0.002301    4.008964e-04
# 8        2.102151      0.014735         0.002502    4.478261e-04
# 9        4.126532      0.022191         0.002701    3.999743e-04
# 10       0.234140      0.017137         0.002501    4.476710e-04
# 11       0.446072      0.002829         0.002301    4.004502e-04
# 12       1.230707      0.008583         0.002401    3.740144e-04
# ...

# %%
dataset.head()
# Out:
#    age     bmi  children      charges  sex_male  smoker_yes
# 0   19  27.900         0  16884.92400     False        True
# 1   18  33.770         1   1725.55230      True       False
# 2   28  33.000         3   4449.46200      True       False
# 3   33  22.705         0  21984.47061      True       False
# 4   32  28.880         0   3866.85520      True       False

# %%
model.predict([[12,26,0,0,1]])
# Out:
# array([16740.88460584])
