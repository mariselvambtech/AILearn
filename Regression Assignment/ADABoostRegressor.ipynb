# %%
import pandas as pd

# %%
dataset = pd.read_csv("insurance_pre.csv")

# %%
dataset = pd.get_dummies(dataset,drop_first=True)

# %%
dataset.head()
# Out:
#    age     bmi  children      charges  sex_male  smoker_yes
# 0   19  27.900         0  16884.92400     False        True
# 1   18  33.770         1   1725.55230      True       False
# 2   28  33.000         3   4449.46200      True       False
# 3   33  22.705         0  21984.47061      True       False
# 4   32  28.880         0   3866.85520      True       False

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
dependent=dataset[[ 'charges']]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(independent,dependent,test_size=0.3)

# %%
type(y_train)
# Out:
# pandas.core.frame.DataFrame

# %%
y_train = y_train.values.flatten()
y_test = y_test.values.flatten()

# %%
y_test.shape
# Out:
# (402,)

# %%
from sklearn.ensemble import AdaBoostRegressor

# %%
model = AdaBoostRegressor(n_estimators=50,random_state=0)

# %%
model.fit(X_train,y_train)
# Out:
# AdaBoostRegressor(random_state=0)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import r2_score,mean_absolute_error

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8535869539923703

# %%
#r2 score is closer to 1.. good !!

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 3785.0067641316223

# %%
#On average, the predicted insurance charges are off by about $3785.0067 compared to the actual charges in the test data.
